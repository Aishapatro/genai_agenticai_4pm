# %% [markdown]
# # Binary system

# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
bin(30)
# Out:
# '0b11110'

# %%
int(0b11110)
# Out:
# 30

# %%
bin(40)
# Out:
# '0b101000'

# %%
int(0b101000)
# Out:
# 40

# %%
bin(345)
# Out:
# '0b101011001'

# %%
int(0b101011001)
# Out:
# 345

# %% [markdown]
# # Octal system

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
oct(44789)
# Out:
# '0o127365'

# %%
int(0o127365)
# Out:
# 44789

# %%
oct(567)
# Out:
# '0o1067'

# %%
int(0o1067)
# Out:
# 567

# %% [markdown]
# # Hexadecimal system

# %%
hex(15)
# Out:
# '0xf'

# %%
hex(25)
# Out:
# '0x19'

# %%
hex(16)
# Out:
# '0x10'

# %%
0xa
# Out:
# 10

# %%
hex(90)
# Out:
# '0x5a'

# %%
hex(1)
# Out:
# '0x1'

# %%
hex(2)
# Out:
# '0x2'

# %%
0x19
# Out:
# 25

# %%
0x15
# Out:
# 21

# %% [markdown]
# # Swap 2- variable

# %%
a=78
b=89

# %%
a=b
b=a

# %%
print(a)
print(b)
# Out:
# 89
# 89

# %%
a=367
b=897

# %%
a=b
b=a

# %%
print(a)
print(b)
# Out:
# 897
# 897

# %% [markdown]
# # Third variable

# %%
a1=86
b1=78

# %%
temp=a1    #with using third variable
a1=b1
b1=temp

# %%
print(a1)
print(b1)
# Out:
# 78
# 86

# %%
a2=35
b2=67

# %%
#without using third variable
a2 = a2 + b2    # 35+67=102
b2 = a2 - b2    # 102-67=35
a2 = a2 - b2    # 102-35=67

# %%
print(a2)
print(b2)
# Out:
# 35
# 67

# %%
bin(67)
# Out:
# '0b1000011'

# %%
int(0b1000011)
# Out:
# 67

# %%
bin(35)
# Out:
# '0b100011'

# %%
int(0b100011)
# Out:
# 35

# %%
print(0b1000011)
print(0b100011)
# Out:
# 67
# 35

# %%
print(0b100011)
print(0b1000011)
# Out:
# 35
# 67

# %%
print(bin(102))
# Out:
# 0b1100110

# %%
print(0b1100110)
# Out:
# 102
