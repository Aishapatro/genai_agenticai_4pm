# %% [markdown]
# # Other datatype to int

# %%
284.96
# Out:
# 284.96

# %%
int(284.96)
# Out:
# 284

# %%
int(True)
# Out:
# 1

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# ### In typecasting while typecast from all other datatype to int possible except complex & text string

# %% [markdown]
# # Other datatype to float

# %%
float(284)
# Out:
# 284.0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(2+9j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 float(2+9j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('30')
# Out:
# 30.0

# %%
float('Thirty')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 float('Thirty')
#
# ValueError: could not convert string to float: 'Thirty'

# %% [markdown]
# # Other datatype to boolean

# %%
bool(2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(2+4j)
# Out:
# True

# %%
bool('50')
# Out:
# True

# %%
bool('fifty')
# Out:
# True

# %%
bool()
# Out:
# False

# %%
bool(-779)
# Out:
# True

# %% [markdown]
# # Other datatyoe to complex

# %%
complex(2)
# Out:
# (2+0j)

# %%
complex(45,67)
# Out:
# (45+67j)

# %%
complex(45,78,90)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 complex(45,78,90)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2.4)
# Out:
# (2.4+0j)

# %%
complex(90.78,4556.789)
# Out:
# (90.78+4556.789j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex('567')
# Out:
# (567+0j)

# %%
complex('six')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 complex('six')
#
# ValueError: complex() arg is a malformed string

# %%
complex('56','890')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 complex('56','890')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex(89,'78064')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 complex(89,'78064')
#
# TypeError: complex() second arg can't be a string

# %% [markdown]
# # Other datatype to string

# %%
str(10)
# Out:
# '10'

# %%
str(56.89)
# Out:
# '56.89'

# %%
str(True)
# Out:
# 'True'

# %%
str(2+56j)
# Out:
# '(2+56j)'
