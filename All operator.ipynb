# %% [markdown]
# # Arithmatic Operator

# %%
x1,y1=10,5

# %%
x1^y1
# Out:
# 15

# %%
x1+y1
# Out:
# 15

# %%
x1-y1
# Out:
# 5

# %%
x1*y1
# Out:
# 50

# %%
x1/y1
# Out:
# 2.0

# %%
x1//y1
# Out:
# 2

# %%
x1%y1
# Out:
# 0

# %%
x1**y1
# Out:
# 100000

# %%
x2=3
y2=2
x2**y2
# Out:
# 9

# %% [markdown]
# # Assignment Operator

# %%
x=2

# %%
x=x+2

# %%
x
# Out:
# 4

# %%
x+=2
x
# Out:
# 6

# %%
x*=2
x
# Out:
# 12

# %%
x-=2
x
# Out:
# 10

# %%
x/=2
x
# Out:
# 5.0

# %%
x//=2
x
# Out:
# 2.0

# %%
a,b=5,6
a
b
# Out:
# 6

# %%
b
# Out:
# 6

# %%
a
# Out:
# 5

# %% [markdown]
# # Unary Operator

# %%
unary means 1 || binary means 2
Here we are applying unary means minus operator (-) on the operand n; the value of m becomes -7,which indicates it as a negative value.

# %%
n=45
n
# Out:
# 45

# %%
m=-(n)
m
# Out:
# -45

# %%
n
# Out:
# 45

# %%
-n
# Out:
# -45

# %% [markdown]
# # Relational Operator

# %%
we are using this operator for comparing

# %%
a=5
b=6

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
 a=b #we cannot use = operator that means it is assigning

# %%
a==b
# Out:
# True

# %%
a!=b
# Out:
# False

# %%
# hear if i change b =6
b=5

# %%
a==b
# Out:
# False

# %%
a
# Out:
# 6

# %%
b
# Out:
# 5

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# False

# %%
a<b
# Out:
# False

# %%
a>b
# Out:
# True

# %%
b=7

# %%
a!=b
# Out:
# True

# %% [markdown]
# # Logical Operator

# %%
Logical operator you need to understand about true & false table.
3 important part of logical operator is AND,OR,NOT.

# %%
a=7
b=9

# %%
a<8 and b<5
# Out:
# False

# %%
a<8 and b<2
# Out:
# False

# %%
a<8 or b<2
# Out:
# True

# %%
a>8 or b<3
# Out:
# False

# %%
x=False
x
# Out:
# False

# %%
not x
# Out:
# True
