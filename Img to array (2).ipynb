# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# pip install pillow

# %%
from PIL import Image  #python imaging library

# %%
image=Image.open(r"C:\Users\aisha\Downloads\Dog.jpg")
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=541x350>

# %%
type(image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
image_arr=np.asarray(image)
image_arr
# Out:
# array([[[204, 100, 123],
#         [204, 100, 123],
#         [204, 100, 123],
#         ...,
#         [238, 167, 185],
#         [238, 167, 185],
#         [238, 167, 185]],
#
#        [[204, 100, 123],
#         [204, 100, 123],
#         [204, 100, 123],
#         ...,
#         [238, 167, 185],
#         [238, 167, 185],
#         [238, 167, 185]],
#
#        [[204, 100, 123],
#         [204, 100, 123],
#         [204, 100, 123],
#         ...,
#         [238, 167, 185],
#         [238, 167, 185],
#         [238, 167, 185]],
#
#        ...,
#
#        [[183,  74,  97],
#         [183,  74,  97],
#         [184,  75,  98],
#         ...,
#         [200,  94, 116],
#         [200,  94, 116],
#         [200,  94, 116]],
#
#        [[183,  74,  97],
#         [183,  74,  97],
#         [183,  74,  97],
#         ...,
#         [200,  94, 116],
#         [200,  94, 116],
#         [200,  94, 116]],
#
#        [[182,  73,  96],
#         [183,  74,  97],
#         [183,  74,  97],
# ...

# %%
image_arr.shape
# Out:
# (350, 541, 3)

# %%
plt.imshow(image_arr)
plt.show()
