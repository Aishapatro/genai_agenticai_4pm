# %% [markdown]
# # Tuple Creation

# %%
t1=()
t1
# Out:
# ()

# %%
t2=(10,29,30)   #int  numbers
t2
# Out:
# (10, 29, 30)

# %%
t3=(12.3,45.9,44.7,78.9)   #float numbers
t3
# Out:
# (12.3, 45.9, 44.7, 78.9)

# %%
t4=('Aisha','Sreeti','Ranu','Priyadarshini')    #Strings
t4
# Out:
# ('Aisha', 'Sreeti', 'Ranu', 'Priyadarshini')

# %%
t5=('Tanisha',23,(12,100),(200,80))   #Nested tuples
t5
# Out:
# ('Tanisha', 23, (12, 100), (200, 80))

# %%
t6=(150,'Aisha',7789.90)  #mixed data types
t6
# Out:
# (150, 'Aisha', 7789.9)

# %%
t7=('Priyadarshini',23,[56,89],[78,45],{'one','two'},(45,90,34))
t7
# Out:
# ('Priyadarshini', 23, [56, 89], [78, 45], {'one', 'two'}, (45, 90, 34))

# %%
len(t7)
# Out:
# 6

# %% [markdown]
# # Tuple Indexing

# %%
t2[0]
# Out:
# 10

# %%
t2[2]
# Out:
# 30

# %%
t4[0]
# Out:
# 'Aisha'

# %%
t4[2]
# Out:
# 'Ranu'

# %%
t4[0][3]
# Out:
# 'h'

# %%
t5[2]
# Out:
# (12, 100)

# %%
t6[-1]
# Out:
# 7789.9

# %%
t7[-3]
# Out:
# [78, 45]

# %% [markdown]
# # Tuple Slicing

# %%
t=('Apple','Mango','Graphes','Orange','Kiwi','Guava','Pear','Dates')
t
# Out:
# ('Apple', 'Mango', 'Graphes', 'Orange', 'Kiwi', 'Guava', 'Pear', 'Dates')

# %%
t[0:2]
# Out:
# ('Apple', 'Mango')

# %%
t[0:5]
# Out:
# ('Apple', 'Mango', 'Graphes', 'Orange', 'Kiwi')

# %%
t[:4]
# Out:
# ('Apple', 'Mango', 'Graphes', 'Orange')

# %%
t[:3]
# Out:
# ('Apple', 'Mango', 'Graphes')

# %%
t[:7]
# Out:
# ('Apple', 'Mango', 'Graphes', 'Orange', 'Kiwi', 'Guava', 'Pear')

# %%
t[::3]
# Out:
# ('Apple', 'Orange', 'Pear')

# %%
t[-2:]
# Out:
# ('Pear', 'Dates')

# %%
t[-6]
# Out:
# 'Graphes'

# %%
t[0]
# Out:
# 'Apple'

# %% [markdown]
# # Remove & change items

# %%
t
# Out:
# ('Apple', 'Mango', 'Graphes', 'Orange', 'Kiwi', 'Guava', 'Pear', 'Dates')

# %%
del t[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 del t[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
t[0]=2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 t[0]=2
#
# TypeError: 'tuple' object does not support item assignment

# %%
del t

# %% [markdown]
# # Loop through a tuple

# %%
t=('Apple','Mango','Graphes','Orange','Kiwi','Guava','Pear','Dates')
t
# Out:
# ('Apple', 'Mango', 'Graphes', 'Orange', 'Kiwi', 'Guava', 'Pear', 'Dates')

# %%
t
# Out:
# ('Apple', 'Mango', 'Graphes', 'Orange', 'Kiwi', 'Guava', 'Pear', 'Dates')

# %%
for i in t:
    print(i)
# Out:
# Apple
# Mango
# Graphes
# Orange
# Kiwi
# Guava
# Pear
# Dates

# %%
for i in enumerate(t):
    print(i)
# Out:
# (0, 'Apple')
# (1, 'Mango')
# (2, 'Graphes')
# (3, 'Orange')
# (4, 'Kiwi')
# (5, 'Guava')
# (6, 'Pear')
# (7, 'Dates')

# %% [markdown]
# # Tuple Membership

# %%
t=('Apple','Mango','Graphes','Orange','Kiwi','Guava','Pear','Dates')
t
# Out:
# ('Apple', 'Mango', 'Graphes', 'Orange', 'Kiwi', 'Guava', 'Pear', 'Dates')

# %%
'Orange' in tuple
# Out:
# True

# %%
'Peach' in tuple
# Out:
# False

# %%
'Graphes' in tuple
# Out:
# True

# %%
if 'Kiwi' in t:
    print('kiwi is present in the tuple')
else:
    print('Kiwi is not present in the tuple')
# Out:
# kiwi is present in the tuple

# %%
if 'Pear' in t:
    print('Pear is present in the tuple')
else:
    print('Pear is not present in the tuple')
# Out:
# Pear is present in the tuple

# %%
if 'Peach' in t:
    print('Peach is present in the tuple')
else:
    print('Peach is not present in the tuple')
# Out:
# Peach is not present in the tuple

# %% [markdown]
# # Index Position

# %%
t
# Out:
# ('Apple', 'Mango', 'Graphes', 'Orange', 'Kiwi', 'Guava', 'Pear', 'Dates')

# %%
t.index('Dates')
# Out:
# 7

# %%
t.index('Mango')
# Out:
# 1

# %%
t.index('Guava')
# Out:
# 5

# %%
t.index('Peach')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 t.index('Peach')
#
# ValueError: tuple.index(x): x not in tuple

# %% [markdown]
# # Sorting

# %%
t9=(12,23,45,89,78,53,49)
t9
# Out:
# (12, 23, 45, 89, 78, 53, 49)

# %%
sorted(t9)
# Out:
# [12, 23, 45, 49, 53, 78, 89]

# %%
sorted(t9,reverse=True)
# Out:
# [89, 78, 53, 49, 45, 23, 12]

# %%
sorted(t9,reverse=False)
# Out:
# [12, 23, 45, 49, 53, 78, 89]
