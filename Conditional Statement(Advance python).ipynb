# %% [raw]
# --> if
# --> else
# --> nested if
# --> if elif else

# %%
if True:
    print('Data Science')
# Out:
# Data Science

# %%
if False:
    print('Data Science')
print('bye')
# Out:
# bye

# %%
if True:
    print('Data Science')
print('bye')
# Out:
# Data Science
# bye

# %%
if True:
    print('Data Science')
else:
    print('bye')
# Out:
# Data Science

# %%
if False:
    print('Data Science')
else:
    print('no job')
# Out:
# no job

# %%
x = 4
r = x % 2

if r == 0:
    print('Even number')
# Out:
# Even number

# %%
x = 5
r = x % 2

if r == 0:
    print('Odd number')

# %%
x = 5
r = x % 2

if r != 0:
    print('Odd number')
# Out:
# Odd number

# %%
x = 7
r = x % 2

if r == 1:
    print('Odd number')
# Out:
# Odd number

# %%
x = 9
r = x % 2 

if r == 0:
    print('Even number')
    
print('odd number')
# Out:
# odd number

# %%
x = 8
r = x % 2 

if r == 0:
    print('Even number')
    
print('odd number')
# Out:
# Even number
# odd number

# %%
x = 11
r = x % 2

if r == 0:
    print('Even number')

if r == 1:
    print('Odd number')
# Out:
# Odd number

# %%
x = 12
r = x % 2

if r == 0:
    print('Even number')

else:
    print('Odd number')
# Out:
# Even number

# %%
x = 13
r = x % 2

if r != 0:
    print('Odd number')

else:
    print('Even number')
# Out:
# Odd number

# %%
x = 3
r = x % 2

if r == 0:
    print('Even number')
    if x>5:
        print('greater number')

else:
    print('Odd number')
# Out:
# Odd number

# %%
x = 4
r = x % 2

if r == 0:
    print('Even number')

    if x>5:
        print('greater number')

else:
    print('Odd number')
# Out:
# Even number

# %%
x = 6
r = x % 2

if r == 0:
    print('Even number')

    if x>5:
        print('greater number')
    else:
        print('smaller number')

else:
    print('Odd number')
# Out:
# Even number
# greater number

# %%
x = 17
r = x % 2

if r == 0:
    print('Even number')

    if x>5:
        print('greater number')
    else:
        print('smaller number')

else:
    print('Odd number')
# Out:
# Odd number

# %%
x = 3

if x == 1:
    print('one')
if x == 2:
    print('Two')
if x == 3:
    print('Three')
if x == 4:
    print('four')
# Out:
# Three

# %%
x = 6

if x == 1:
    print('one')
if x == 2:
    print('Two')
if x == 3:
    print('Three')
if x == 4:
    print('four')

# %%
age = 19
if age > 18:
    print("Eligible to  vote.")
# Out:
# Eligible to  vote.
